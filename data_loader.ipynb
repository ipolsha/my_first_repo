# %%
import pandas as pd

raw_data = pd.read_excel('C:\MyPythonProjects\my_first_repo\data\siRNAmod_db_parsed_concs.xlsx')
raw_data.head(10)
# Out:
#    SMDBid                                       Field1_links  \
# 0  SM5329  http://crdd.osdd.net/servers/sirnamod/record.p...
# 1  SM5328  http://crdd.osdd.net/servers/sirnamod/record.p...
# 2  SM5327  http://crdd.osdd.net/servers/sirnamod/record.p...
# 3  SM5326  http://crdd.osdd.net/servers/sirnamod/record.p...
# 4  SM5325  http://crdd.osdd.net/servers/sirnamod/record.p...
# 5  SM5324  http://crdd.osdd.net/servers/sirnamod/record.p...
# 6  SM5323  http://crdd.osdd.net/servers/sirnamod/record.p...
# 7  SM5322  http://crdd.osdd.net/servers/sirnamod/record.p...
# 8  SM5321  http://crdd.osdd.net/servers/sirnamod/record.p...
# 9  SM5320  http://crdd.osdd.net/servers/sirnamod/record.p...
#
#              siRNA sense        siRNA antisense          Modification sense  \
# 0  AAAUCAUGGUGAAAUAAAAUU  UUUUAUUUCACCAUGAUUUUU  Inverted abasic* 2-Methoxy
# 1  AUAAGGCUAUGAAGAGAUATT  UAUCUCUUCAUAGCCUUAUTT    Inverted abasic* 2-Deoxy
# ...

# %%
df = pd.read_excel('C:\MyPythonProjects\my_first_repo\data\siRNAmod_db_parsed_details_done.xlsx')
df.head(10)
# Out:
#   SMDB_id                         Efficacy Experiment used to check activity  \
# 0  SM5329  EC-50 = 0.02 nM for target mRNA        Real-time quantitative PCR
# 1  SM5328   EC-50 = 0.6 nM for target mRNA        Real-time quantitative PCR
# 2  SM5327  EC-50 = 0.14 nM for target mRNA        Real-time quantitative PCR
# 3  SM5326  EC-50 = 0.05 nM for target mRNA        Real-time quantitative PCR
# 4  SM5325  EC-50 = 0.51 nM for target mRNA        Real-time quantitative PCR
# 5  SM5324  EC-50 = 0.44 nM for target mRNA        Real-time quantitative PCR
# 6  SM5323  EC-50 = 0.02 nM for target mRNA        Real-time quantitative PCR
# 7  SM5322  EC-50 = 0.19 nM for target mRNA        Real-time quantitative PCR
# 8  SM5321  EC-50 = 0.13 nM for target mRNA        Real-time quantitative PCR
# 9  SM5320  EC-50 = 0.05 nM for target mRNA        Real-time quantitative PCR
#
#   Melting point (°C)      Target gene siRNA concentration  \
# 0                NaN         SSB gene                 NaN
# ...
